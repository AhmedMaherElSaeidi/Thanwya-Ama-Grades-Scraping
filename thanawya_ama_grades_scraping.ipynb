# %% [markdown]
# # Thanawya ama grades scraping jupyter notebook
# ### Scrapping `g12.emis.gov.eg` for students grades
# ![g12.emis.gov.eg](./data/img/screencapture-g12-emis-gov-eg.png)

# %%
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
students_data = []
url = "https://g12.emis.gov.eg/"
error_msg = 'يرجى مراجعة لجنة النظام والمراقبة التابع لها الطالب' # SeatNo not found
seat_numbers = list(map(str, range(1077439,1897338))) # Inputs => 1002583 ---> 1897338

# %%
def getGrades(subject):
    dictionary = {}
    
    for index, subject in enumerate(subject):
        if(index == 0):
            continue
            
        subject_name = subject.th.string.strip()
        subject_grade = subject.th.next_sibling.next_sibling.string.strip()
        dictionary[subject_name] = subject_grade
    
    return dictionary

# %%
def getStudentData(soup):
    dictionary = {}    
    student_details = soup.find_all('table')[0].tbody.find_all('tr')
    primary_subjects = soup.find_all('table')[1].find_all('tr')
    secondary_subjects = soup.find_all('table')[2].find_all('tr')
    
    #Student details        
    dictionary['seat_num'] = student_details[0].td.string.strip()
    dictionary['student_name'] = student_details[1].td.string.strip()
    dictionary['school_name'] = student_details[2].td.string.strip()
    for student_detail in student_details[3:]:
        dictionary[student_detail.th.string.strip()] = student_detail.th.next_sibling.next_sibling.string.strip()
    dictionary['status'] = soup.find_all(attrs={'id':"Result"})[0].find('h2').string.strip()
    
    #Student grades
    dictionary.update(getGrades(primary_subjects))
    dictionary.update(getGrades(secondary_subjects))
    
    return dictionary

# %%
try:
    # Get the path to chromedriver
    driver_path = ChromeDriverManager().install()

    # Create a Chrome webdriver
    driver = webdriver.Chrome()

    for seat_number in seat_numbers:
        # Open the URL in the browser
        driver.get(url)

        # Find the input element by its name attribute
        input_element = driver.find_element('id', 'SeatingNo')

        # Enter the seat number in the input field
        input_element.send_keys(seat_number)

        # Submit the form
        input_element.submit()

        # Get the current page source (HTML content) after the form submission
        response_text = driver.page_source
        
        if error_msg in response_text:
            continue
            
        soup = BeautifulSoup(response_text, 'html.parser')
        students_data.append(getStudentData(soup))
        
except Exception as e:
    print(f"Error: {e}")

finally:
    # Close the browser
    driver.quit()
# Out:
# Error: list index out of range

# %% [markdown]
# ### Convert the `studenst_data` array to a DataFrame

# %%
df = pd.DataFrame(students_data)

df.replace(np.nan, 0, inplace=True)
df.sort_values(by='seat_num', ascending=True, axis=0, inplace=True)

df.rename(columns={'اللغة العربية':'arabic', 'التاريخ':'history', 'اللغة الأجنبية الثانية':'second_language', 'اللغة الأجنبية الأولى':'first_language', 'المجموع الكلى':'total',
                  'علم النفس والإجتماع':'psychology_sociology', 'الفلسفة والمنطق':'philosophy_logic', 'الجغرافيا':'geography', 'الفيزياء':'physics',
                   'الكيمياء':'chemistry', 'الجيولوجيا وعلوم البيئة':'geology', 'الأحياء':'biology', 'الرياضيات التطبيقية':'applied_mathematics', 
                  'الرياضيات البحتة':'pure_mathematics', "التربية الدينية":'religion', "التربية الوطنية":'national_education',
                  'الإقتصاد والإحصاء':'Economics_statistics', 'الإحصاء':'statistics'}, inplace=True)

# %%
print(df.shape)
subjects = df.columns[9:]
df.columns.to_frame()
# Out:
# (108, 26)
#                                          0
# seat_num                          seat_num
# student_name                  student_name
# school_name                    school_name
# المديرية                          المديرية
# الإدارة                            الإدارة
# اسم اللجنة                      اسم اللجنة
# عنوان اللجنة                  عنوان اللجنة
# الهاتف                              الهاتف
# status                              status
# arabic                              arabic
# first_language              first_language
# second_language            second_language
# history                            history
# geography                        geography
# philosophy_logic          philosophy_logic
# psychology_sociology  psychology_sociology
# total                                total
# religion                          religion
# national_education      national_education
# Economics_statistics  Economics_statistics
# biology                            biology
# geology                            geology
# chemistry                        chemistry
# physics                            physics
# pure_mathematics          pure_mathematics
# applied_mathematics    applied_mathematics

# %% [markdown]
# ### Merging Frames

# %%
# df_old = pd.read_csv('./data/thanawya2023_part1.csv')
# df = df_old.append(df)

print(f'Before dropping duplicates {df.shape}')
df = df.drop_duplicates()
print(f'After dropping duplicates {df.shape}')
# Out:
# Before dropping duplicates (108, 26)
# After dropping duplicates (108, 26)

# %%
# Replacing Subjects values with a translated values
df.loc[:,subjects] = df.loc[:,subjects].replace('غياب','absence')
df.loc[:,subjects] = df.loc[:,subjects].replace('مؤجـل','postponed')
df.loc[:,subjects] = df.loc[:,subjects].replace('معفـي','exempt')
df.loc[:,subjects] = df.loc[:,subjects].replace('إجتاز','passed')
df.loc[:,subjects] = df.loc[:,subjects].replace('ملغـي','cancelled')
df.loc[:,subjects] = df.loc[:,subjects].replace('نصـف','0.5')
df.loc[:,subjects] = df.loc[:,subjects].replace('واحـد','1')
df.loc[:,subjects] = df.loc[:,subjects].replace('صفـر','0')
df.loc[:,subjects] = df.loc[:,subjects].replace(np.nan, 0)

# %%
for i in range(4, df.shape[1]):
    print(f' {df.columns[i]} : {df.iloc[:,i].unique()}', "\n"*3)
# Out:
#  الإدارة : ['الشيخ زايد']
#
#
#
#  اسم اللجنة : ['لجنة النظام والمراقبة قطاع القاهرة أ']
#
#
#
#  عنوان اللجنة : ['مدرسة السنية الثانوية بنات بالسيدة زينب']
#
#
#
#  الهاتف : ['0223911294-0223958589']
#
#
#
#  status : ['ناجـح' 'دور ثان' 'راسـب']
#
#
#
#  arabic : ['45.5' '42.5' '40' '43' '53.5' '41' '48.5' '54.5' '44' '59.5' '50' '51.5'
#  '18.5' '42' '41.5' '47.5' '45' '27.5' '44.5' '50.5' '40.5' '52' '26.5'
#  '28' '51' '43.5' 'absence' '48' '29' '47' '55.5' '29.5' '63.5' '23.5'
#  '57' '49.5']
#
#
#
#  first_language : ['26' '12' '25' '35' '27.5' '29.5' '32' '31' '10.5' 'absence' '28.5' '9'
#  '3.5' '37.5' '26.5' '11.5' '11' '10' '43']
#
#
#
#  second_language : ['20' '6' '6.5' '27.5' '32.5' '31.5' '34' '28.5' '22' '35' '30.5' '22.5'
#  '25.5' '24.5' '31' '26' '9' '20.5' '21.5' '5' '8' '21' '23.5' 'absence'
#  '27' '8.5' '7.5' '9.5' '36.5' '7' '23']
#
#
#
#  history : ['36' '30' '39' '41' '44' '35' '34.5' '43.5' '41.5' 0 '30.5' 'absence'
#  '13' '32.5' '14' '12' '37' '12.5' '10' '38']
#
#
#
#  geography : ['32' '45' '50' '43' '52' '30' '47' '37' '51' '48' 0 '39' '40' 'absence'
#  '46.5' '12' '35' '41' '31' '18' '36' '38.5' '39.5' '34.5' '42.5' '33.5'
#  '32.5' '35.5' '37.5' '40.5' '43.5' '36.5' '30.5' '19' '45.5']
#
#
#
#  philosophy_logic : ['34.5' '37' '43.5' '30' '40' '30.5' '45' '43' '44' 0 '19.5' '33.5' '35.5'
#  '41.5' '31.5' 'absence' '42' '34' '41' '32.5' '35' '38' '33' '15' '39.5'
#  '36.5' '32']
#
#
#
#  psychology_sociology : ['32.5' '34' '35' '31' '38' '36' '33' '40' '43' '47' 0 '31.5' '33.5' '42'
#  '30' 'absence' '37' '41.5' '45' '34.5' '38.5' '41' '44' '49.5' '39.5'
#  '42.5' '32' '39' '19']
#
#
#
#  total : ['226.5' '220.5' '252.5' '209' '269.5' '221' '218.5' '227.5' '287' '266'
#  '302' '283' '162.5' '171.5' '146.5' '176.5' '157' '230' '229' '204.5'
#  '195.5' '206.5' '185' '200.5' '189' '212.5' '204' '167' '186.5' '200'
#  '188' '214' '177.5' '139' '175.5' '111.5' '166.5' '179' '166' '183.5'
#  '154' '130.5' '117' '138' '190' '207.5' '213' '248.5' '228.5' '210.5' '0'
#  '270' '221.5' '159' '226' '227' '247' '193.5' '220' '209.5' '217.5' '207'
#  '217' '224' '195' '180' '223.5' '186' '213.5' '197' '237.5' '254' '196'
#  '244' '143' '238.5' '273.5' '211.5' '232.5' '168' '190.5' '194' '215.5'
#  '243.5' '267' '181.5' '223' '205' '210' '181' '259' '196.5' '198']
#
#
#
#  religion : ['20' '21' '18' '19' '15' '16' '17' '22' '14' '13' '10']
#
#
#
#  national_education : ['16' '17' '21' '18' '15' '19' '20' '13' '14' '6']
#
#
#
#  Economics_statistics : ['25' '13' '29' '26' 'absence' '11' '10' '28' '7' '12']
#
#
#
#  biology : [0 '12.5' '30' '13.5' '9.5' '33' '35' '34' '33.5' '37']
#
#
#
#  geology : [0 '21' '12' '19.5' '17.5' 'absence' '44.5' '40.5' '31' '20.5' '31.5' '26'
#  '24.5' '34.5' '30' '33' '22' '23.5' '26.5' '18']
#
#
#
#  chemistry : [0 '14' '30' '13' 'absence' '14.5' '31' '11' '0.5' '33' '9']
#
#
#
#  physics : [0 '30' '12.5' '32.5' '13' '5' '10' '10.5' 'absence' '9' '11.5' '7.5']
#
#
#
#  pure_mathematics : [0 'absence' '15' '18' '20.5' '20' '19' '21.5' '14' '12.5' '9' '13']
#
#
#
#  applied_mathematics : [0 'absence' '18.5' '14.5' '21' '12' '17' '20.5' '30' '10' '13']

# %%
# Replacing Status values with a translated values
df['status'] = df['status'].replace('راسـب', 'fail')
df['status'] = df['status'].replace('دور ثان', 'second round')
df['status'] = df['status'].replace('ناجـح', 'pass')
df['status'].unique()
# Out:
# array(['pass', 'second round', 'fail'], dtype=object)

# %%
df['seat_num'] = df['seat_num'].map(int)
df.sort_values(by='seat_num', ascending=True, axis=0, inplace=True)
df.to_csv('./data/thanawya2023_part2.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# ### Viewing csv file

# %%
df = pd.read_csv('./data/thanawya2023_part2.csv')
df.shape
# Out:
# (108, 28)

# %%
df.head()
# Out:
#    seat_num              student_name gender  school_name المديرية  \
# 0   1077439       مهند محمد احمد احمد      M  خدمات ثانوي   الجيزة
# 1   1077440  نورالدين ايمن السيد محمد      M  خدمات ثانوي   الجيزة
# 2   1077441   وليد مصطفي بدري اسماعيل      M  خدمات ثانوي   الجيزة
# 3   1077442      يوسف احمد محمد محمود      M  خدمات ثانوي   الجيزة
# 4   1077443   يوسف خالد محمد ابوالحسن      M  خدمات ثانوي   الجيزة
#
#                              اسم اللجنة     الإدارة  \
# 0  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 1  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 2  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 3  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 4  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
#
#                               عنوان اللجنة                 الهاتف     section  \
# 0  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589  literature
# 1  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589  literature
# 2  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589  literature
# 3  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589  literature
# 4  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589  literature
#
#    ... psychology_sociology  chemistry physics pure_mathematics  \
# 0  ...                 32.5          0       0                0
# 1  ...                   34          0       0                0
# 2  ...                   35          0       0                0
# 3  ...                   31          0       0                0
# 4  ...                   38          0       0                0
#
#   applied_mathematics biology geology religion national_education  \
# 0                   0     0.0       0       20                 16
# 1                   0     0.0       0       20                 17
# 2                   0     0.0       0       20                 17
# 3                   0     0.0       0       20                 16
# 4                   0     0.0       0       21                 21
#
#   Economics_statistics
# 0                   25
# 1                   13
# 2                   25
# 3                   25
# 4                   25
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#      seat_num                student_name gender       school_name المديرية  \
# 103   1077544           ملك عادل سيد ثابت      F  خدمات الشيخ زايد   الجيزة
# 104   1077545         منه وليد درويش محمد      F  خدمات الشيخ زايد   الجيزة
# 105   1077546             مي سيد حسين سيد      F  خدمات الشيخ زايد   الجيزة
# 106   1077547      ميار ابراهيم رفيق امين      F  خدمات الشيخ زايد   الجيزة
# 107   1077548  نانسي حسام رمضان محمد خليل      F  خدمات الشيخ زايد   الجيزة
#
#                                اسم اللجنة     الإدارة  \
# 103  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 104  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 105  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 106  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
# 107  لجنة النظام والمراقبة قطاع القاهرة أ  الشيخ زايد
#
#                                 عنوان اللجنة                 الهاتف  \
# 103  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589
# 104  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589
# 105  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589
# 106  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589
# 107  مدرسة السنية الثانوية بنات بالسيدة زينب  0223911294-0223958589
#
#         section  ... psychology_sociology  chemistry physics pure_mathematics  \
# 103  literature  ...                   35          0       0                0
# 104  literature  ...                   30          0       0                0
# 105  literature  ...                 42.5          0       0                0
# 106  literature  ...                   35          0       0                0
# 107  literature  ...                   34          0       0                0
#
#     applied_mathematics biology geology religion national_education  \
# 103                   0     0.0       0       13                 16
# 104                   0     0.0       0       10                 13
# 105                   0     0.0       0       15                 14
# 106                   0     0.0       0       13                 15
# 107                   0     0.0       0       13                 17
#
#     Economics_statistics
# 103                   12
# 104                   25
# 105                   25
# 106                   25
# 107                   25
#
# [5 rows x 28 columns]
